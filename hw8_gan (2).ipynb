# %% [markdown]
# ## Подключение необходимых библиотек

# %%
# !git clone https://github.com/tensorflow/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23066, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 23066 (delta 6), reused 7 (delta 0), pack-reused 23038
# Receiving objects: 100% (23066/23066), 42.18 MiB | 18.88 MiB/s, done.
# Resolving deltas: 100% (12654/12654), done.

# %%
cd examples
# Out:
# /content/examples

# %%
# !python setup.py build
# Out:
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:561: UserWarning: The version specified ('5bc9f1ed519146242db5e71f00d9d39d52a308c8\n') is an invalid version, this may not work as expected with newer versions of setuptools, pip, and PyPI. Please see PEP 440 for more details.
#   warnings.warn(
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/tensorflow_examples
# copying tensorflow_examples/__init__.py -> build/lib/tensorflow_examples
# creating build/lib/tensorflow_examples/lite
# copying tensorflow_examples/lite/__init__.py -> build/lib/tensorflow_examples/lite
# creating build/lib/tensorflow_examples/models
# copying tensorflow_examples/models/__init__.py -> build/lib/tensorflow_examples/models
# creating build/lib/tensorflow_examples/lite/model_maker
# copying tensorflow_examples/lite/model_maker/__init__.py -> build/lib/tensorflow_examples/lite/model_maker
# creating build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/image_classification_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/custom_model_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/custom_model_demo_test.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/question_answer_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/recommendation_demo_test.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/recommendation_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/audio_classification_demo_test.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/image_classification_demo_test.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/text_classification_demo_test.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/audio_classification_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# copying tensorflow_examples/lite/model_maker/demo/text_classification_demo.py -> build/lib/tensorflow_examples/lite/model_maker/demo
# creating build/lib/tensorflow_examples/lite/model_maker/cli
# copying tensorflow_examples/lite/model_maker/cli/cli_test.py -> build/lib/tensorflow_examples/lite/model_maker/cli
# copying tensorflow_examples/lite/model_maker/cli/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/cli
# copying tensorflow_examples/lite/model_maker/cli/cli.py -> build/lib/tensorflow_examples/lite/model_maker/cli
# creating build/lib/tensorflow_examples/lite/model_maker/core
# copying tensorflow_examples/lite/model_maker/core/export_format.py -> build/lib/tensorflow_examples/lite/model_maker/core
# copying tensorflow_examples/lite/model_maker/core/compat.py -> build/lib/tensorflow_examples/lite/model_maker/core
# copying tensorflow_examples/lite/model_maker/core/file_util.py -> build/lib/tensorflow_examples/lite/model_maker/core
# copying tensorflow_examples/lite/model_maker/core/test_util.py -> build/lib/tensorflow_examples/lite/model_maker/core
# copying tensorflow_examples/lite/model_maker/core/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core
# creating build/lib/tensorflow_examples/lite/model_maker/public
# copying tensorflow_examples/lite/model_maker/public/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public
# creating build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/deprecated_api.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/golden_api_doc.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/api_util.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/api_gen_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/api_util_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/api_gen.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# copying tensorflow_examples/lite/model_maker/core/api/include.py -> build/lib/tensorflow_examples/lite/model_maker/core/api
# creating build/lib/tensorflow_examples/lite/model_maker/core/utils
# copying tensorflow_examples/lite/model_maker/core/utils/ondevice_scann_builder.py -> build/lib/tensorflow_examples/lite/model_maker/core/utils
# copying tensorflow_examples/lite/model_maker/core/utils/scann_converter_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/utils
# copying tensorflow_examples/lite/model_maker/core/utils/scann_converter.py -> build/lib/tensorflow_examples/lite/model_maker/core/utils
# copying tensorflow_examples/lite/model_maker/core/utils/ondevice_scann_builder_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/utils
# copying tensorflow_examples/lite/model_maker/core/utils/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/utils
# creating build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/custom_model.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/audio_classifier_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/object_detector_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/audio_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/image_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writer_for_image_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/image_preprocessing.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/model_util.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/train_image_classifier_lib.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/image_preprocessing_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/text_classifier_v1_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/searcher.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/image_classifier_v1_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/configs.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/classification_model_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/image_classifier_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/model_util_v1_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/recommendation_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/question_answer.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/question_answer_v1_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/searcher_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/question_answer_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/hub_loader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/custom_model_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/text_classifier_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/classification_model.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/object_detector.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/hub_loader.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/model_util_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/recommendation.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# copying tensorflow_examples/lite/model_maker/core/task/text_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task
# creating build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/audio_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/object_detector_dataloader_util_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/recommendation_testutil.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/metadata_loader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/image_searcher_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/image_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/searcher_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/metadata_loader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/text_searcher_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/searcher_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/object_detector_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/recommendation_config.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/text_searcher_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/text_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/recommendation_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/data_util.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/object_detector_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/image_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/image_searcher_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/recommendation_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/object_detector_dataloader_util.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/audio_dataloader_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# copying tensorflow_examples/lite/model_maker/core/data_util/text_dataloader.py -> build/lib/tensorflow_examples/lite/model_maker/core/data_util
# creating build/lib/tensorflow_examples/lite/model_maker/core/optimization
# copying tensorflow_examples/lite/model_maker/core/optimization/warmup.py -> build/lib/tensorflow_examples/lite/model_maker/core/optimization
# copying tensorflow_examples/lite/model_maker/core/optimization/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/optimization
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/metadata_writer.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/image_spec.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/object_detector_spec_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/object_detector_spec.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/util.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/text_spec_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/recommendation_spec.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/audio_spec_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/text_spec.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/model_spec_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/audio_spec.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# copying tensorflow_examples/lite/model_maker/core/task/model_spec/recommendation_spec_test.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/model_spec
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/text_classifier
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/text_classifier/metadata_writer_for_text_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/text_classifier
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/text_classifier/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/text_classifier
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/metadata_writer_for_bert.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/text_classifier
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/text_classifier/metadata_writer_for_bert_text_classifier.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/text_classifier
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/text_classifier/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/text_classifier
# creating build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/question_answerer
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/question_answerer/metadata_writer_for_bert_question_answerer.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/question_answerer
# copying tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/question_answerer/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/core/task/metadata_writers/bert/question_answerer
# creating build/lib/tensorflow_examples/lite/model_maker/public/question_answer
# copying tensorflow_examples/lite/model_maker/public/question_answer/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/question_answer
# creating build/lib/tensorflow_examples/lite/model_maker/public/searcher
# copying tensorflow_examples/lite/model_maker/public/searcher/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/searcher
# creating build/lib/tensorflow_examples/lite/model_maker/public/text_classifier
# copying tensorflow_examples/lite/model_maker/public/text_classifier/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/text_classifier
# creating build/lib/tensorflow_examples/lite/model_maker/public/recommendation
# copying tensorflow_examples/lite/model_maker/public/recommendation/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/recommendation
# creating build/lib/tensorflow_examples/lite/model_maker/public/config
# copying tensorflow_examples/lite/model_maker/public/config/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/config
# creating build/lib/tensorflow_examples/lite/model_maker/public/image_classifier
# copying tensorflow_examples/lite/model_maker/public/image_classifier/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/image_classifier
# creating build/lib/tensorflow_examples/lite/model_maker/public/model_spec
# copying tensorflow_examples/lite/model_maker/public/model_spec/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/model_spec
# creating build/lib/tensorflow_examples/lite/model_maker/public/audio_classifier
# copying tensorflow_examples/lite/model_maker/public/audio_classifier/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/audio_classifier
# creating build/lib/tensorflow_examples/lite/model_maker/public/object_detector
# copying tensorflow_examples/lite/model_maker/public/object_detector/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/object_detector
# creating build/lib/tensorflow_examples/lite/model_maker/public/recommendation/spec
# copying tensorflow_examples/lite/model_maker/public/recommendation/spec/__init__.py -> build/lib/tensorflow_examples/lite/model_maker/public/recommendation/spec
# creating build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/distributed_train.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/utils.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/densenet.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/densenet_distributed_test.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/train.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/__init__.py -> build/lib/tensorflow_examples/models/densenet
# copying tensorflow_examples/models/densenet/densenet_test.py -> build/lib/tensorflow_examples/models/densenet
# creating build/lib/tensorflow_examples/models/dcgan
# copying tensorflow_examples/models/dcgan/dcgan.py -> build/lib/tensorflow_examples/models/dcgan
# copying tensorflow_examples/models/dcgan/__init__.py -> build/lib/tensorflow_examples/models/dcgan
# copying tensorflow_examples/models/dcgan/dcgan_test.py -> build/lib/tensorflow_examples/models/dcgan
# creating build/lib/tensorflow_examples/models/pix2pix
# copying tensorflow_examples/models/pix2pix/pix2pix_test.py -> build/lib/tensorflow_examples/models/pix2pix
# copying tensorflow_examples/models/pix2pix/pix2pix.py -> build/lib/tensorflow_examples/models/pix2pix
# copying tensorflow_examples/models/pix2pix/__init__.py -> build/lib/tensorflow_examples/models/pix2pix
# copying tensorflow_examples/models/pix2pix/data_download.py -> build/lib/tensorflow_examples/models/pix2pix
# creating build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/distributed_train.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/utils.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/nmt.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/nmt_test.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/distributed_test.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/train.py -> build/lib/tensorflow_examples/models/nmt_with_attention
# copying tensorflow_examples/models/nmt_with_attention/__init__.py -> build/lib/tensorflow_examples/models/nmt_with_attention

# %%
import tensorflow as tf
tf.config.experimental.set_visible_devices([], 'GPU')

# %%
import tensorflow_datasets as tfds
from tensorflow_examples.models.pix2pix import pix2pix

import os
import time
import matplotlib.pyplot as plt
from keras.datasets.cifar10 import load_data
from IPython.display import clear_output

tfds.disable_progress_bar()
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ## Загрузка и обработка данных

# %%
dataset, metadata = tfds.load('cycle_gan/horse2zebra',
                              with_info=True, as_supervised=True)

train_horses, train_zebras = dataset['trainA'], dataset['trainB']
test_horses, test_zebras = dataset['testA'], dataset['testB']
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cycle_gan/horse2zebra/2.0.0...
# Dataset cycle_gan downloaded and prepared to /root/tensorflow_datasets/cycle_gan/horse2zebra/2.0.0. Subsequent calls will reuse this data.

# %%
BUFFER_SIZE = 1000
BATCH_SIZE = 1
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
def random_crop(image):
  cropped_image = tf.image.random_crop(
      image, size=[IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image

# %%
# normalizing the images to [-1, 1]
def normalize(image):
  image = tf.cast(image, tf.float32)
  image = (image / 127.5) - 1
  return image

# %%
def random_jitter(image):
  # resizing to 286 x 286 x 3
  image = tf.image.resize(image, [286, 286],
                          method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  # randomly cropping to 256 x 256 x 3
  image = random_crop(image)

  # random mirroring
  image = tf.image.random_flip_left_right(image)

  return image

# %%
def preprocess_image_train(image, label):
  image = random_jitter(image)
  image = normalize(image)
  return image

# %%
def preprocess_image_test(image, label):
  image = normalize(image)
  return image

# %%
train_horses = train_horses.map(
    preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

train_zebras = train_zebras.map(
    preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

test_horses = test_horses.map(
    preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

test_zebras = test_zebras.map(
    preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

# %%
sample_horse = next(iter(train_horses))
sample_zebra = next(iter(train_zebras))

# %%
plt.subplot(121)
plt.title('Horse')
plt.imshow(sample_horse[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Horse with random jitter')
plt.imshow(random_jitter(sample_horse[0]) * 0.5 + 0.5)

# %%
plt.subplot(121)
plt.title('Zebra')
plt.imshow(sample_zebra[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Zebra with random jitter')
plt.imshow(random_jitter(sample_zebra[0]) * 0.5 + 0.5)

# %% [markdown]
# ## Импортирование  Pix2Pix модели

# %% [markdown]
# Генератор и дискриминатор мы возьмем из Pix2Pix модели, генерация будет осуществляться с применением Unet.

# %%
OUTPUT_CHANNELS = 3

generator_g = pix2pix.unet_generator(OUTPUT_CHANNELS, norm_type='instancenorm')
generator_f = pix2pix.unet_generator(OUTPUT_CHANNELS, norm_type='instancenorm')

discriminator_x = pix2pix.discriminator(norm_type='instancenorm', target=False)
discriminator_y = pix2pix.discriminator(norm_type='instancenorm', target=False)

# %%
to_zebra = generator_g(sample_horse)
to_horse = generator_f(sample_zebra)
plt.figure(figsize=(8, 8))
contrast = 8

imgs = [sample_horse, to_zebra, sample_zebra, to_horse]
title = ['Horse', 'To Zebra', 'Zebra', 'To Horse']

for i in range(len(imgs)):
  plt.subplot(2, 2, i+1)
  plt.title(title[i])
  if i % 2 == 0:
    plt.imshow(imgs[i][0] * 0.5 + 0.5)
  else:
    plt.imshow(imgs[i][0] * 0.5 * contrast + 0.5)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(8, 8))

plt.subplot(121)
plt.title('Is a real zebra?')
plt.imshow(discriminator_y(sample_zebra)[0, ..., -1], cmap='RdBu_r')

plt.subplot(122)
plt.title('Is a real horse?')
plt.imshow(discriminator_x(sample_horse)[0, ..., -1], cmap='RdBu_r')

plt.show()

# %% [markdown]
# ## Loss functions

# %% [markdown]
# Loss функции для генератора и дискриминатора можно взять также из [pix2pix](https://www.tensorflow.org/tutorials/generative/pix2pix#define_the_loss_functions_and_the_optimizer).

# %%
LAMBDA = 10

# %%
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real, generated):
  real_loss = loss_obj(tf.ones_like(real), real)

  generated_loss = loss_obj(tf.zeros_like(generated), generated)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss * 0.5

# %%
def generator_loss(generated):
  return loss_obj(tf.ones_like(generated), generated)

# %%
def calc_cycle_loss(real_image, cycled_image):
  loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))
  
  return LAMBDA * loss1

# %%
def identity_loss(real_image, same_image):
  loss = tf.reduce_mean(tf.abs(real_image - same_image))
  return LAMBDA * 0.5 * loss

# %% [markdown]
# Инициализация оптимайзеров для всех генераторов и всех дискриминаторов.

# %%
generator_g_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
generator_f_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

discriminator_x_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_y_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %% [markdown]
# ## Checkpoints

# %% [markdown]
# Сохранение промежуточных результатов, для того, чтобы при необходимости можно было продолжить обучение, а не начинать сначала.

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(generator_g=generator_g,
                           generator_f=generator_f,
                           discriminator_x=discriminator_x,
                           discriminator_y=discriminator_y,
                           generator_g_optimizer=generator_g_optimizer,
                           generator_f_optimizer=generator_f_optimizer,
                           discriminator_x_optimizer=discriminator_x_optimizer,
                           discriminator_y_optimizer=discriminator_y_optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %% [markdown]
# ## Training

# %%
EPOCHS = 10

# %%
def generate_images(model, test_input):
  prediction = model(test_input)
    
  plt.figure(figsize=(12, 12))

  display_list = [test_input[0], prediction[0]]
  title = ['Input Image', 'Predicted Image']

  for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
@tf.function
def train_step(real_x, real_y):
  # persistent is set to True because the tape is used more than
  # once to calculate the gradients.
  with tf.GradientTape(persistent=True) as tape:
    # Generator G translates X -> Y
    # Generator F translates Y -> X.
    
    fake_y = generator_g(real_x, training=True)
    cycled_x = generator_f(fake_y, training=True)

    fake_x = generator_f(real_y, training=True)
    cycled_y = generator_g(fake_x, training=True)

    # same_x and same_y are used for identity loss.
    same_x = generator_f(real_x, training=True)
    same_y = generator_g(real_y, training=True)

    disc_real_x = discriminator_x(real_x, training=True)
    disc_real_y = discriminator_y(real_y, training=True)

    disc_fake_x = discriminator_x(fake_x, training=True)
    disc_fake_y = discriminator_y(fake_y, training=True)

    # calculate the loss
    gen_g_loss = generator_loss(disc_fake_y)
    gen_f_loss = generator_loss(disc_fake_x)
    
    total_cycle_loss = calc_cycle_loss(real_x, cycled_x) + calc_cycle_loss(real_y, cycled_y)
    
    # Total generator loss = adversarial loss + cycle loss
    total_gen_g_loss = gen_g_loss + total_cycle_loss + identity_loss(real_y, same_y)
    total_gen_f_loss = gen_f_loss + total_cycle_loss + identity_loss(real_x, same_x)

    disc_x_loss = discriminator_loss(disc_real_x, disc_fake_x)
    disc_y_loss = discriminator_loss(disc_real_y, disc_fake_y)
  
  # Calculate the gradients for generator and discriminator
  generator_g_gradients = tape.gradient(total_gen_g_loss, 
                                        generator_g.trainable_variables)
  generator_f_gradients = tape.gradient(total_gen_f_loss, 
                                        generator_f.trainable_variables)
  
  discriminator_x_gradients = tape.gradient(disc_x_loss, 
                                            discriminator_x.trainable_variables)
  discriminator_y_gradients = tape.gradient(disc_y_loss, 
                                            discriminator_y.trainable_variables)
  
  # Apply the gradients to the optimizer
  generator_g_optimizer.apply_gradients(zip(generator_g_gradients, 
                                            generator_g.trainable_variables))

  generator_f_optimizer.apply_gradients(zip(generator_f_gradients, 
                                            generator_f.trainable_variables))
  
  discriminator_x_optimizer.apply_gradients(zip(discriminator_x_gradients,
                                                discriminator_x.trainable_variables))
  
  discriminator_y_optimizer.apply_gradients(zip(discriminator_y_gradients,
                                                discriminator_y.trainable_variables))

# %%
for epoch in range(EPOCHS):
  start = time.time()

  n = 0
  for image_x, image_y in tf.data.Dataset.zip((train_horses, train_zebras)):
    train_step(image_x, image_y)
    if n % 10 == 0:
      print ('.', end='')
    n+=1

  clear_output(wait=True)
  # Using a consistent image (sample_horse) so that the progress of the model
  # is clearly visible.
  generate_images(generator_g, sample_horse)

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                         ckpt_save_path))

  print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                      time.time()-start))
# Out:
# Time taken for epoch 1 is 8015.761259794235 sec
#
# ...........................................................................
